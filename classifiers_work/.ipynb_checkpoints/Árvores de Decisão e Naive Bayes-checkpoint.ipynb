# %% [markdown]
# ### Machine Learning - PPG IC-UFF 2017.1
# # Árvore de Decisão e Naive Bayes

# %% [markdown]
# ## 1 - Árvore de Decisão

# %%
from sklearn.datasets import load_iris
import numpy as np
iris_data = load_iris()
iris_data.data
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
#        [ 5.2,  3.4,  1.4,  0.2],
#        [ 4.7,  3.2,  1.6,  0.2],
#        [ 4.8,  3.1,  1.6,  0.2],
#        [ 5.4,  3.4,  1.5,  0.4],
#        [ 5.2,  4.1,  1.5,  0.1],
#        [ 5.5,  4.2,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5. ,  3.2,  1.2,  0.2],
#        [ 5.5,  3.5,  1.3,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 4.4,  3. ,  1.3,  0.2],
#        [ 5.1,  3.4,  1.5,  0.2],
#        [ 5. ,  3.5,  1.3,  0.3],
#        [ 4.5,  2.3,  1.3,  0.3],
#        [ 4.4,  3.2,  1.3,  0.2],
#        [ 5. ,  3.5,  1.6,  0.6],
#        [ 5.1,  3.8,  1.9,  0.4],
#        [ 4.8,  3. ,  1.4,  0.3],
#        [ 5.1,  3.8,  1.6,  0.2],
#        [ 4.6,  3.2,  1.4,  0.2],
#        [ 5.3,  3.7,  1.5,  0.2],
#        [ 5. ,  3.3,  1.4,  0.2],
#        [ 7. ,  3.2,  4.7,  1.4],
#        [ 6.4,  3.2,  4.5,  1.5],
#        [ 6.9,  3.1,  4.9,  1.5],
#        [ 5.5,  2.3,  4. ,  1.3],
#        [ 6.5,  2.8,  4.6,  1.5],
#        [ 5.7,  2.8,  4.5,  1.3],
#        [ 6.3,  3.3,  4.7,  1.6],
#        [ 4.9,  2.4,  3.3,  1. ],
#        [ 6.6,  2.9,  4.6,  1.3],
#        [ 5.2,  2.7,  3.9,  1.4],
#        [ 5. ,  2. ,  3.5,  1. ],
#        [ 5.9,  3. ,  4.2,  1.5],
#        [ 6. ,  2.2,  4. ,  1. ],
#        [ 6.1,  2.9,  4.7,  1.4],
#        [ 5.6,  2.9,  3.6,  1.3],
#        [ 6.7,  3.1,  4.4,  1.4],
#        [ 5.6,  3. ,  4.5,  1.5],
#        [ 5.8,  2.7,  4.1,  1. ],
#        [ 6.2,  2.2,  4.5,  1.5],
#        [ 5.6,  2.5,  3.9,  1.1],
#        [ 5.9,  3.2,  4.8,  1.8],
#        [ 6.1,  2.8,  4. ,  1.3],
#        [ 6.3,  2.5,  4.9,  1.5],
#        [ 6.1,  2.8,  4.7,  1.2],
#        [ 6.4,  2.9,  4.3,  1.3],
#        [ 6.6,  3. ,  4.4,  1.4],
#        [ 6.8,  2.8,  4.8,  1.4],
#        [ 6.7,  3. ,  5. ,  1.7],
#        [ 6. ,  2.9,  4.5,  1.5],
#        [ 5.7,  2.6,  3.5,  1. ],
#        [ 5.5,  2.4,  3.8,  1.1],
#        [ 5.5,  2.4,  3.7,  1. ],
#        [ 5.8,  2.7,  3.9,  1.2],
#        [ 6. ,  2.7,  5.1,  1.6],
#        [ 5.4,  3. ,  4.5,  1.5],
#        [ 6. ,  3.4,  4.5,  1.6],
#        [ 6.7,  3.1,  4.7,  1.5],
#        [ 6.3,  2.3,  4.4,  1.3],
#        [ 5.6,  3. ,  4.1,  1.3],
#        [ 5.5,  2.5,  4. ,  1.3],
#        [ 5.5,  2.6,  4.4,  1.2],
#        [ 6.1,  3. ,  4.6,  1.4],
#        [ 5.8,  2.6,  4. ,  1.2],
#        [ 5. ,  2.3,  3.3,  1. ],
#        [ 5.6,  2.7,  4.2,  1.3],
#        [ 5.7,  3. ,  4.2,  1.2],
#        [ 5.7,  2.9,  4.2,  1.3],
#        [ 6.2,  2.9,  4.3,  1.3],
#        [ 5.1,  2.5,  3. ,  1.1],
#        [ 5.7,  2.8,  4.1,  1.3],
#        [ 6.3,  3.3,  6. ,  2.5],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 7.1,  3. ,  5.9,  2.1],
#        [ 6.3,  2.9,  5.6,  1.8],
#        [ 6.5,  3. ,  5.8,  2.2],
#        [ 7.6,  3. ,  6.6,  2.1],
#        [ 4.9,  2.5,  4.5,  1.7],
#        [ 7.3,  2.9,  6.3,  1.8],
#        [ 6.7,  2.5,  5.8,  1.8],
#        [ 7.2,  3.6,  6.1,  2.5],
#        [ 6.5,  3.2,  5.1,  2. ],
#        [ 6.4,  2.7,  5.3,  1.9],
#        [ 6.8,  3. ,  5.5,  2.1],
#        [ 5.7,  2.5,  5. ,  2. ],
#        [ 5.8,  2.8,  5.1,  2.4],
#        [ 6.4,  3.2,  5.3,  2.3],
#        [ 6.5,  3. ,  5.5,  1.8],
#        [ 7.7,  3.8,  6.7,  2.2],
#        [ 7.7,  2.6,  6.9,  2.3],
#        [ 6. ,  2.2,  5. ,  1.5],
#        [ 6.9,  3.2,  5.7,  2.3],
#        [ 5.6,  2.8,  4.9,  2. ],
#        [ 7.7,  2.8,  6.7,  2. ],
#        [ 6.3,  2.7,  4.9,  1.8],
#        [ 6.7,  3.3,  5.7,  2.1],
#        [ 7.2,  3.2,  6. ,  1.8],
#        [ 6.2,  2.8,  4.8,  1.8],
#        [ 6.1,  3. ,  4.9,  1.8],
#        [ 6.4,  2.8,  5.6,  2.1],
#        [ 7.2,  3. ,  5.8,  1.6],
#        [ 7.4,  2.8,  6.1,  1.9],
#        [ 7.9,  3.8,  6.4,  2. ],
#        [ 6.4,  2.8,  5.6,  2.2],
#        [ 6.3,  2.8,  5.1,  1.5],
#        [ 6.1,  2.6,  5.6,  1.4],
#        [ 7.7,  3. ,  6.1,  2.3],
#        [ 6.3,  3.4,  5.6,  2.4],
#        [ 6.4,  3.1,  5.5,  1.8],
#        [ 6. ,  3. ,  4.8,  1.8],
#        [ 6.9,  3.1,  5.4,  2.1],
#        [ 6.7,  3.1,  5.6,  2.4],
#        [ 6.9,  3.1,  5.1,  2.3],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 6.8,  3.2,  5.9,  2.3],
#        [ 6.7,  3.3,  5.7,  2.5],
#        [ 6.7,  3. ,  5.2,  2.3],
#        [ 6.3,  2.5,  5. ,  1.9],
#        [ 6.5,  3. ,  5.2,  2. ],
#        [ 6.2,  3.4,  5.4,  2.3],
#        [ 5.9,  3. ,  5.1,  1.8]])

# %%
class DecisionTree():
    def __init__(self, params=None):
        'If params is None the method is initialized with default values.'
        pass
    
    def predict(X):
        pass
    
    def learn(X,y):
        pass

# %% [markdown]
# ## 2 - Naive Bayes

# %%
class NaiveBayes():
    def __init__(self, params=None):
        'If params is None the method is initialized with default values.'
        pass
    
    def predict(X):
        pass
    
    def learn(X,y):
        pass
    
    def class_prior_probabilities(X,y):
        data_lenght = len(y)
        class_types = list(set(y))
        for clas in class_types:
            class_idx =  [i for i, label in enumerate(y) if label == clas]
        class_idx

# %%
X = iris_data.data
y = iris_data.target
class_idx = {}
class_probs = {}
for clas in list(set(y)):
    class_idx[clas] = [i for i, label in enumerate(y) if label == clas]
    class_probs[clas] = len(class_idx[clas]) / len(y)
    
features_probs = {}
for i,column in enumerate(np.array(X).T):
    features_probs[i] = {} 
    for value in list(set(column)):
        features_probs[i][value] = len([x for x in column if x == value]) / len(column)
        #TODO
        conditional_probs = {}
# Out:
# {0: {4.2999999999999998: 0.006666666666666667,
#   4.4000000000000004: 0.02,
#   4.5: 0.006666666666666667,
#   4.5999999999999996: 0.02666666666666667,
#   4.7000000000000002: 0.013333333333333334,
#   4.7999999999999998: 0.03333333333333333,
#   4.9000000000000004: 0.04,
#   5.0: 0.06666666666666667,
#   5.0999999999999996: 0.06,
#   5.2000000000000002: 0.02666666666666667,
#   5.2999999999999998: 0.006666666666666667,
#   5.4000000000000004: 0.04,
#   5.5: 0.04666666666666667,
#   5.5999999999999996: 0.04,
#   5.7000000000000002: 0.05333333333333334,
#   5.7999999999999998: 0.04666666666666667,
#   5.9000000000000004: 0.02,
#   6.0: 0.04,
#   6.0999999999999996: 0.04,
#   6.2000000000000002: 0.02666666666666667,
#   6.2999999999999998: 0.06,
#   6.4000000000000004: 0.04666666666666667,
#   6.5: 0.03333333333333333,
#   6.5999999999999996: 0.013333333333333334,
#   6.7000000000000002: 0.05333333333333334,
#   6.7999999999999998: 0.02,
#   6.9000000000000004: 0.02666666666666667,
#   7.0: 0.006666666666666667,
#   7.0999999999999996: 0.006666666666666667,
#   7.2000000000000002: 0.02,
#   7.2999999999999998: 0.006666666666666667,
#   7.4000000000000004: 0.006666666666666667,
#   7.5999999999999996: 0.006666666666666667,
#   7.7000000000000002: 0.02666666666666667,
#   7.9000000000000004: 0.006666666666666667},
#  1: {2.0: 0.006666666666666667,
#   2.2000000000000002: 0.02,
#   2.2999999999999998: 0.02666666666666667,
#   2.3999999999999999: 0.02,
#   2.5: 0.05333333333333334,
#   2.6000000000000001: 0.03333333333333333,
#   2.7000000000000002: 0.06,
#   2.7999999999999998: 0.09333333333333334,
#   2.8999999999999999: 0.06666666666666667,
#   3.0: 0.17333333333333334,
#   3.1000000000000001: 0.08,
#   3.2000000000000002: 0.08666666666666667,
#   3.2999999999999998: 0.04,
#   3.3999999999999999: 0.08,
#   3.5: 0.04,
#   3.6000000000000001: 0.02,
#   3.7000000000000002: 0.02,
#   3.7999999999999998: 0.04,
#   3.8999999999999999: 0.013333333333333334,
#   4.0: 0.006666666666666667,
#   4.0999999999999996: 0.006666666666666667,
#   4.2000000000000002: 0.006666666666666667,
#   4.4000000000000004: 0.006666666666666667},
#  2: {1.0: 0.006666666666666667,
#   1.1000000000000001: 0.006666666666666667,
#   1.2: 0.013333333333333334,
#   1.3: 0.04666666666666667,
#   1.3999999999999999: 0.08,
#   1.5: 0.09333333333333334,
#   1.6000000000000001: 0.04666666666666667,
#   1.7: 0.02666666666666667,
#   1.8999999999999999: 0.013333333333333334,
#   3.0: 0.006666666666666667,
#   3.2999999999999998: 0.013333333333333334,
#   3.5: 0.013333333333333334,
#   3.6000000000000001: 0.006666666666666667,
#   3.7000000000000002: 0.006666666666666667,
#   3.7999999999999998: 0.006666666666666667,
#   3.8999999999999999: 0.02,
#   4.0: 0.03333333333333333,
#   4.0999999999999996: 0.02,
#   4.2000000000000002: 0.02666666666666667,
#   4.2999999999999998: 0.013333333333333334,
#   4.4000000000000004: 0.02666666666666667,
#   4.5: 0.05333333333333334,
#   4.5999999999999996: 0.02,
#   4.7000000000000002: 0.03333333333333333,
#   4.7999999999999998: 0.02666666666666667,
#   4.9000000000000004: 0.03333333333333333,
#   5.0: 0.02666666666666667,
#   5.0999999999999996: 0.05333333333333334,
#   5.2000000000000002: 0.013333333333333334,
#   5.2999999999999998: 0.013333333333333334,
#   5.4000000000000004: 0.013333333333333334,
#   5.5: 0.02,
#   5.5999999999999996: 0.04,
#   5.7000000000000002: 0.02,
#   5.7999999999999998: 0.02,
#   5.9000000000000004: 0.013333333333333334,
#   6.0: 0.013333333333333334,
#   6.0999999999999996: 0.02,
#   6.2999999999999998: 0.006666666666666667,
#   6.4000000000000004: 0.006666666666666667,
#   6.5999999999999996: 0.006666666666666667,
#   6.7000000000000002: 0.013333333333333334,
#   6.9000000000000004: 0.006666666666666667},
#  3: {0.10000000000000001: 0.04,
#   0.20000000000000001: 0.18666666666666668,
#   0.29999999999999999: 0.04666666666666667,
#   0.40000000000000002: 0.04666666666666667,
#   0.5: 0.006666666666666667,
#   0.59999999999999998: 0.006666666666666667,
#   1.0: 0.04666666666666667,
#   1.1000000000000001: 0.02,
#   1.2: 0.03333333333333333,
#   1.3: 0.08666666666666667,
#   1.3999999999999999: 0.05333333333333334,
#   1.5: 0.08,
#   1.6000000000000001: 0.02666666666666667,
#   1.7: 0.013333333333333334,
#   1.8: 0.08,
#   1.8999999999999999: 0.03333333333333333,
#   2.0: 0.04,
#   2.1000000000000001: 0.04,
#   2.2000000000000002: 0.02,
#   2.2999999999999998: 0.05333333333333334,
#   2.3999999999999999: 0.02,
#   2.5: 0.02}}
